# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import math

# %%
def MyModel (n=1,N=1000,k=100, error=False, mu=0,sigma=0.1, a=10, fun=np.sin):
    
    X=np.linspace(-a*np.pi, a*np.pi,N)
    Y=fun(X)
    
    X_train=np.linspace(-a*np.pi,a*np.pi,k)
    Y_train=fun(X_train)
    if(error == True):
        Y_train+=np.random.normal(mu,sigma,k)
    
    model = np.poly1d(np.polyfit(X_train, Y_train, n))
    
    plt.plot(X,Y,'darkgreen',label="истинное значение")
    plt.plot(X_train,Y_train,'bv',label="эмпирические данные")
    plt.plot(X,model(X),'r',label="обученная модель")
    plt.legend(bbox_to_anchor=(1.1, 1))
    plt.show()

# %%
#underfitting from 0 to 6
#perfect 10
#overfitting from 11

# %%
MyModel()

# %%
MyModel(n=11)

# %%
MyModel(n=13)

# %%
MyModel(n=17)

# %%
MyModel(n=24)

# %%
MyModel(n=27)

# %%
MyModel(n=29)

# %%
MyModel(n=31)

# %%
MyModel(n=35)

# %%
MyModel(n=37)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: RankWarning: Polyfit may be poorly conditioned
#   # This is added back by InteractiveShellApp.init_path()

# %%
MyModel(n=9,error=True)

# %%
MyModel(n=12,error=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: RankWarning: Polyfit may be poorly conditioned
#   # This is added back by InteractiveShellApp.init_path()

# %%
MyModel(n=28, fun=stats.norm.pdf,k=30)

# %%
MyModel(n=19,error=True, fun=stats.norm.pdf,k=30, sigma=0.01)

# %%
N=100
k=13
fun=np.sin
a=2
group=5

X=np.linspace(-a*np.pi, a*np.pi,N)
Y=fun(X)
    
X_data=np.linspace(-a*np.pi,a*np.pi,k)#упорядоченное разбие множества 
Y_data=fun(X_data)
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_data, Y_data, test_size=0.2, random_state=10)

# %%
plt.scatter(X_train, Y_train)
plt.show()

# %%
plt.scatter(X_test, Y_test)
plt.show()

# %%
n=11
model = np.poly1d(np.polyfit(X_train, Y_train, n))
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RankWarning: Polyfit may be poorly conditioned

# %%
A=model(X_test)-Y_test

# %%
np.sqrt(A@A)
# Out:
# 0.09629567951606054

# %%
A
# Out:
# array([ 0.03645468, -0.00878244, -0.08869489])
